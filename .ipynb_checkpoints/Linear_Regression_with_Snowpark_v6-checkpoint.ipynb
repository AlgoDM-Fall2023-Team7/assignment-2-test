# %% [markdown]
# # Linear Regression
#
#
# An ecommerce retailer is looking to use machine learning to understand its customer's online engagement with its digital outlets i.e website and app. It is trying to decide whether to focus its efforts on the mobile app experience or website. We will use Linear Regression model to see which user acitivity has the biggest impact on their likelyhood of spending more money.
#
# #### Variables of interest:
# Avg. Session Length: Average session of in-store style advice sessions.<br>
# Time on App: Average time spent on App in minutes <br>
# Time on Website: Average time spent on Website in minutes <br>
# Length of Membership: How many years the customer has been a member <br>

# %%
# !pip install ipykernel

# !python -m ipykernel install --user --name snowpark-de-ml --display-name "Snowpark DE ML"
# Out:
# Requirement already satisfied: ipykernel in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (6.25.0)
# Requirement already satisfied: appnope in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: packaging in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: backcall in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: typing-extensions in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.7.1)
# Requirement already satisfied: exceptiongroup in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (1.0.4)
# Requirement already satisfied: pexpect>4.3 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: entrypoints in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.3+snowflake1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: asttokens in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/aj/opt/anaconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Installed kernelspec snowpark-de-ml in /Users/aj/Library/Jupyter/kernels/snowpark-de-ml

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Importing necesaary packages (including Snowpark)
# If any of the packages do not exist in your Python environment you can install them using conda. Here is an example of installing seaborn visualization package
#
# *import sys <br>
# !conda install --yes --prefix {sys.prefix} seaborn*

# %%
# Snowpark
import json

# Plotting
import matplotlib.pyplot as plt
import numpy as np
# Pandas & json
import pandas as pd
import seaborn as sns
#from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.linear_model import LinearRegression
# Models
from sklearn.model_selection import train_test_split
from snowflake.snowpark import functions as F
from snowflake.snowpark.functions import pandas_udf
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import *
from snowflake.snowpark.version import VERSION

# %matplotlib inline

# %%
# !pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (3.2.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (1.15.1)
# Requirement already satisfied: cryptography<42.0.0,>=3.1.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (41.0.3)
# Requirement already satisfied: oscrypto<2.0.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (1.2.1)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (23.2.0)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (3.15.0)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: pytz in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (2.31.0)
# Requirement already satisfied: packaging in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (2023.7.22)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (4.7.1)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (3.12.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<3.9.0,>=2.6.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (3.8.1)
# Requirement already satisfied: tomlkit in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: pycparser in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)

# %%
# !pip install snowflake
# Out:
# Requirement already satisfied: snowflake in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (0.0.4)

# %%
# !pip install snowflake-snowpark-Python
# Out:
# Requirement already satisfied: snowflake-snowpark-Python in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (1.9.0)
# Requirement already satisfied: setuptools>=40.6.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-snowpark-Python) (68.0.0)
# Requirement already satisfied: wheel in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-snowpark-Python) (0.41.2)
# Requirement already satisfied: snowflake-connector-python<4.0.0,>=3.2.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-snowpark-Python) (3.2.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-snowpark-Python) (4.7.1)
# Requirement already satisfied: pyyaml in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-snowpark-Python) (6.0.1)
# Requirement already satisfied: cloudpickle<=2.0.0,>=1.6.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-snowpark-Python) (2.0.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (1.15.1)
# Requirement already satisfied: cryptography<42.0.0,>=3.1.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (41.0.3)
# Requirement already satisfied: oscrypto<2.0.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (1.2.1)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (23.2.0)
# Requirement already satisfied: pycryptodomex!=3.5.0,<4.0.0,>=3.2 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (3.15.0)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (2.4.0)
# Requirement already satisfied: pytz in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (2.31.0)
# Requirement already satisfied: packaging in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (2023.7.22)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (3.12.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (2.4.0)
# Requirement already satisfied: platformdirs<3.9.0,>=2.6.0 in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (3.8.1)
# Requirement already satisfied: tomlkit in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (0.11.1)
# Requirement already satisfied: pycparser in /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0,>=3.2.0->snowflake-snowpark-Python) (2.21)

# %% [markdown]
# ### Set context

# %%
# Read credentials
with open('creds_generic.json') as f:
    connection_parameters = json.load(f)
session = Session.builder.configs(connection_parameters).create()

# %%
snowpark_version = VERSION
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Role                        : {}'.format(session.get_current_role()))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Database                    : "ML_SFDEMO"
# Schema                      : "ML_DEMO"
# Warehouse                   : "COMPUTE_WH"
# Role                        : "ACCOUNTADMIN"
# Snowpark for Python version : 1.9.0

# %% [markdown]
# ### Data Loading

# %%
customers = pd.read_csv("EcommerceCustomers.csv")
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
# Create a Snowpark DF from the pandas DF
snowdf = session.createDataFrame(customers)

# %%
snowdf.show(2)
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"Email"                    |"Address"                   |"Avatar"   |"Avg. Session Length"  |"Time on App"       |"Time on Website"   |"Length of Membership"  |"Yearly Amount Spent"  |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |mstephenson@fernandez.com  |835 Frank Tunnel            |Violet     |34.49726772511229      |12.655651149166752  |39.57766801952616   |4.082620632952961       |587.9510539684005      |
# |                           |Wrightmouth, MI 82180-9605  |           |                       |                    |                    |                        |                       |
# |hduke@hotmail.com          |4547 Archer Common          |DarkGreen  |31.926272026360156     |11.109460728682564  |37.268958868297744  |2.66403418213262        |392.2049334443264      |
# |                           |Diazchester, CA 06566-8576  |           |                       |                    |                    |                        |                       |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Loading customer data from Snowpark DF to a Snowflake internal table

snowdf.write.mode("overwrite").saveAsTable("customers_new")

session.table("CUSTOMERS_NEW").limit(3).show(5)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"Email"                    |"Address"                       |"Avatar"   |"Avg. Session Length"  |"Time on App"       |"Time on Website"   |"Length of Membership"  |"Yearly Amount Spent"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |mstephenson@fernandez.com  |835 Frank Tunnel                |Violet     |34.49726772511229      |12.655651149166752  |39.57766801952616   |4.082620632952961       |587.9510539684005      |
# |                           |Wrightmouth, MI 82180-9605      |           |                       |                    |                    |                        |                       |
# |hduke@hotmail.com          |4547 Archer Common              |DarkGreen  |31.926272026360156     |11.109460728682564  |37.268958868297744  |2.66403418213262        |392.2049334443264      |
# |                           |Diazchester, CA 06566-8576      |           |                       |                    |                    |                        |                       |
# |pallen@yahoo.com           |24645 Valerie Unions Suite 582  |Bisque     |33.000914755642675     |11.330278057777512  |37.11059744212085   |4.104543202376424       |487.54750486747207     |
# |                           |Cobbborough, DC 99414-7564      |           |                       |                    |                    |                        |                       |
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Create a pandas data frame from the Snowflake table
custdf = session.table('CUSTOMERS_NEW').toPandas()

print(f"'custdf' local dataframe created. Number of records: {len(custdf)} ")
# Out:
# 'custdf' local dataframe created. Number of records: 500

# %% [markdown]
# ### Model Training & Testing

# %%
# Start by understanding the correlation matrix for the new data frame
# Filter out non-numeric columns
numeric_cols = custdf.select_dtypes(include=[np.number])

# Visualize the correlation heatmap
f, ax = plt.subplots(figsize=(10, 8))
ax.set_title('Encoded Correlation Heatmap for Used Vehicles Dataset', pad=12)
sns.heatmap(numeric_cols.corr(), vmin=-1, vmax=1, annot=True, cmap='Spectral')
plt.show()

# %%
# Define X and Y for modeling
X = custdf[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
Y = custdf['Yearly Amount Spent']

# %%
# Split into training & Testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                 test_size=0.3, random_state=101)

# %% [markdown]
# #### Linear Regression - Predict Yearly Spend

# %%
# Create an instance of Linear Regression and Fit the training datasets
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Creating a User Defined Function within Snowflake to do the scoring there
def predict_pandas_udf(df: pd.DataFrame) -> pd.Series:
    return pd.Series(lm.predict(df))

linear_model_vec = pandas_udf(func=predict_pandas_udf,
                                return_type=FloatType(),
                                input_types=[FloatType(),FloatType(),FloatType(),FloatType()],
                                session=session,
                                packages = ("pandas","scikit-learn"), max_batch_size=200)

# %%
# Calling the UDF to do the scoring (pushing down to Snowflake)
output = session.table('CUSTOMERS_NEW').select(*list(X.columns),
                    linear_model_vec(list(X.columns)).alias('PREDICTED_SPEND'),
                    (F.col('Yearly Amount Spent')).alias('ACTUAL_SPEND')
                    )

output.show(5)
# Out:
# Passing arguments to a UDF with a list or tuple is deprecated. We still respect this invocation but please consider passing variable-length arguments without a list or tuple.
# --------------------------------------------------------------------------------------------------------------------------------------
# |"Avg. Session Length"  |"Time on App"       |"Time on Website"   |"Length of Membership"  |"PREDICTED_SPEND"   |"ACTUAL_SPEND"      |
# --------------------------------------------------------------------------------------------------------------------------------------
# |34.49726772511229      |12.655651149166752  |39.57766801952616   |4.082620632952961       |594.458382229991    |587.9510539684005   |
# |31.926272026360156     |11.109460728682564  |37.268958868297744  |2.66403418213262        |380.62290937131206  |392.2049334443264   |
# |33.000914755642675     |11.330278057777512  |37.11059744212085   |4.104543202376424       |505.3081071362801   |487.54750486747207  |
# |34.30555662975554      |13.717513665142508  |36.72128267790313   |3.1201787827480914      |570.9334360377882   |581.8523440352178   |
# |33.33067252364639      |12.795188551078114  |37.53665330059473   |4.446308318351435       |591.4310342994036   |599.4060920457634   |
# --------------------------------------------------------------------------------------------------------------------------------------

# %%
# Save the predicted output as a table on Snowflake
###used later in Streamlit app
output.write.mode("overwrite").saveAsTable("PREDICTED_CUSTOMER_SPEND")

# Also get a local dataframe to review the results
output=output.toPandas()

# %% [markdown]
# ##### Plotting and comparing the predicted values with actual spend values

# %%
# Plot a descriptive scatter of predicted and actual values
x = output.index
y1 = output["ACTUAL_SPEND"]
y2 = output["PREDICTED_SPEND"]

f, ax = plt.subplots(figsize=(14, 8))
plt.scatter(x, y1, c='tab:blue', s=y1/5)
plt.scatter(x, y2, c='tab:red', s=y2/20)

plt.title(f"Actual Spend vs Predicted Spend - Linear Regression")
plt.ylabel("ACTUAL + PREDICTED SPEND")
plt.xlabel("CUSTOMER IDs")
ax.grid(True)
plt.show()

# %% [markdown]
# *To start with, define a function for regression metrics*
#
# 1. R² measures how much variability in dependent variable can be "explained by the model.
# 2. While R² is a relative measure of how well the model fits dependent variables, Mean Square Error is an absolute measure of the goodness for the fit.
# 3. Mean Absolute Error(MAE) is similar to MSE, however, unlike MSE, MAE takes the sum of the ABSOLUTE value of error.
#
# *[Regression Merics Reference](https://towardsdatascience.com/regression-an-explanation-of-regression-metrics-and-what-can-go-wrong-a39a9793d914)*

# %%
#1 & 2 Coefficient of Determination (R² & Adjusted R²)
print("\n--- Coefficient of Determination (R²) ---")
r2 = metrics.r2_score(y_pred=y2, y_true=y1)
print(f"R²: {round(r2, 2)}")

#3 & 4. MSE and RMSE
print("\n--- Mean Squared Error (MSE & RMSE) ---")

mse = metrics.mean_squared_error(y_pred=y2, y_true=y1, squared=True)
rmse = metrics.mean_squared_error(y_pred=y2, y_true=y1, squared=False)

print(f"MSE: {round(mse, 2)}")
print(f"RMSE: {round(rmse, 2)}")


#5. MAE
print("\n--- Mean Absolute Error (MAE) ---")
mae = metrics.mean_absolute_error(y_pred=y2, y_true=y1)
print(f"MAE: {round(mae, 2)}")
# Out:
# --- Coefficient of Determination (R²) ---
# R²: 0.98
#
# --- Mean Squared Error (MSE & RMSE) ---
# MSE: 98.74
# RMSE: 9.94
#
# --- Mean Absolute Error (MAE) ---
# MAE: 7.9

# %%
# Distribution of differences between actual and predicted values
# Gaussian kernel density estimate.

sns.displot((y2-y1),bins=50, kde=True, legend=True, height=6, aspect=2);
# Out:
# /Users/sneharokkam/miniconda3/envs/snowpark-de-ml/lib/python3.9/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Get coefficients from the fitted model
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient']).round(2)
coeff_df
# Out:
#                       Coefficient
# Avg. Session Length         25.98
# Time on App                 38.59
# Time on Website              0.19
# Length of Membership        61.28

# %% [markdown]
# ### Conclusion
# Time spent on the app and Length of Membership are most important factors driving customer spend. The retailer should focus its efforts on increasing stickiness to its app and enhance its loyalty programs.

# %%
import joblib  # Import joblib
# ... (your model training code) ...

# Save the trained model to a file
joblib.dump(lm, 'linear_regression_model_with_snowpark.pkl')
# Out:
# ['linear_regression_model_with_snowpark.pkl']
